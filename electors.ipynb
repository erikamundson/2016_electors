# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %%
df = pd.read_excel('excel/federalelections2016.xlsx', sheet_name=2).head(51)

# %%
df.head()
# Out:
#   STATE Trump (R) Clinton (D)  Trump (R).1  Clinton (D).1  All Others  \
# 0    AL         9         NaN    1318255.0       729547.0     75570.0
# 1    AK         3         NaN     163387.0       116454.0     38767.0
# 2    AZ        11         NaN    1252401.0      1161167.0    159597.0
# 3    AR         6         NaN     684872.0       380494.0     65310.0
# 4    CA       NaN          55    4483814.0      8753792.0    943998.0
#
#    Total Vote
# 0   2123372.0
# 1    318608.0
# 2   2573165.0
# 3   1130676.0
# 4  14181604.0

# %%
df['Viable Votes'] = df['Trump (R).1'] + df['Clinton (D).1']

# %%
df.head()
# Out:
#   STATE Trump (R) Clinton (D)  Trump (R).1  Clinton (D).1  All Others  \
# 0    AL         9         NaN    1318255.0       729547.0     75570.0
# 1    AK         3         NaN     163387.0       116454.0     38767.0
# 2    AZ        11         NaN    1252401.0      1161167.0    159597.0
# 3    AR         6         NaN     684872.0       380494.0     65310.0
# 4    CA       NaN          55    4483814.0      8753792.0    943998.0
#
#    Total Vote  Viable Votes
# 0   2123372.0     2047802.0
# 1    318608.0      279841.0
# 2   2573165.0     2413568.0
# 3   1130676.0     1065366.0
# 4  14181604.0    13237606.0

# %%
df['Electors'] = [9,3,11,6,55,9,7,3,3,29,16,4,4,20,11,6,6,8,8,4,10,11,16,10,6,10,3,5,6,4,14,5,29,15,3,18,7,7,20,4,9,3,11,38,6,3,13,12,5,10,3]

# %%
df
# Out:
#    STATE Trump (R) Clinton (D)  Trump (R).1  Clinton (D).1  All Others  \
# 0     AL         9         NaN    1318255.0       729547.0     75570.0
# 1     AK         3         NaN     163387.0       116454.0     38767.0
# 2     AZ        11         NaN    1252401.0      1161167.0    159597.0
# 3     AR         6         NaN     684872.0       380494.0     65310.0
# 4     CA       NaN          55    4483814.0      8753792.0    943998.0
# 5     CO       NaN           9    1202484.0      1338870.0    238893.0
# 6     CT       NaN           7     673215.0       897572.0     74133.0
# 7     DE       NaN           3     185127.0       235603.0     23084.0
# 8     DC       NaN           3      12723.0       282830.0     15715.0
# 9     FL        29         NaN    4617886.0      4504975.0    297178.0
# 10    GA        16         NaN    2089104.0      1877963.0    147665.0
# 11    HI       NaN         3**     128847.0       266891.0     33199.0
# 12    ID         4         NaN     409055.0       189765.0     91435.0
# 13    IL       NaN          20    2146015.0      3090729.0    299680.0
# 14    IN        11         NaN    1557286.0      1033126.0    144546.0
# 15    IA         6         NaN     800983.0       653669.0    111379.0
# 16    KS         6         NaN     671018.0       427005.0     86379.0
# 17    KY         8         NaN    1202971.0       628854.0     92324.0
# 18    LA         8         NaN    1178638.0       780154.0     70240.0
# 19    ME         1           3     335593.0       357735.0     54599.0
# 20    MD       NaN          10     943169.0      1677928.0    160349.0
# 21    MA       NaN          11    1090893.0      1995196.0    238957.0
# 22    MI        16         NaN    2279543.0      2268839.0    250902.0
# 23    MN       NaN          10    1322951.0      1367716.0    254146.0
# 24    MS         6         NaN     700714.0       485131.0     23512.0
# 25    MO        10         NaN    1594511.0      1071068.0    143026.0
# 26    MT         3         NaN     279240.0       177709.0     40198.0
# 27    NE         5         NaN     495961.0       284494.0     63772.0
# 28    NV       NaN           6     512058.0       539260.0     74067.0
# 29    NH       NaN           4     345790.0       348526.0     49980.0
# 30    NJ       NaN          14    1601933.0      2148278.0    123835.0
# 31    NM       NaN           5     319667.0       385234.0     93418.0
# 32    NY       NaN          29    2819533.0      4556118.0    345791.0
# 33    NC        15         NaN    2362631.0      2189316.0    189617.0
# 34    ND         3         NaN     216794.0        93758.0     33808.0
# 35    OH        18         NaN    2841005.0      2394164.0    261318.0
# 36    OK         7         NaN     949136.0       420375.0     83481.0
# 37    OR       NaN           7     782403.0      1002106.0    216827.0
# 38    PA        20         NaN    2970733.0      2926441.0    268304.0
# 39    RI       NaN           4     180543.0       252525.0     31076.0
# 40    SC         9         NaN    1155389.0       855373.0     92265.0
# 41    SD         3         NaN     227721.0       117458.0     24914.0
# 42    TN        11         NaN    1522925.0       870695.0    114407.0
# 43    TX       36*         NaN    4685047.0      3877868.0    406311.0
# 44    UT         6         NaN     515231.0       310676.0    305523.0
# 45    VT       NaN           3      95369.0       178573.0     41125.0
# 46    VA       NaN          13    1769443.0      1981473.0    233715.0
# 47    WA       NaN         8**    1221747.0      1742718.0    352554.0
# 48    WV         5         NaN     489371.0       188794.0     36258.0
# 49    WI        10         NaN    1405284.0      1382536.0    188330.0
# 50    WY         3         NaN     174419.0        55973.0     25457.0
#
#     Total Vote  Viable Votes  Electors
# 0    2123372.0     2047802.0         9
# 1     318608.0      279841.0         3
# 2    2573165.0     2413568.0        11
# 3    1130676.0     1065366.0         6
# 4   14181604.0    13237606.0        55
# 5    2780247.0     2541354.0         9
# 6    1644920.0     1570787.0         7
# 7     443814.0      420730.0         3
# 8     311268.0      295553.0         3
# 9    9420039.0     9122861.0        29
# 10   4114732.0     3967067.0        16
# 11    428937.0      395738.0         4
# 12    690255.0      598820.0         4
# 13   5536424.0     5236744.0        20
# 14   2734958.0     2590412.0        11
# 15   1566031.0     1454652.0         6
# 16   1184402.0     1098023.0         6
# 17   1924149.0     1831825.0         8
# 18   2029032.0     1958792.0         8
# 19    747927.0      693328.0         4
# 20   2781446.0     2621097.0        10
# 21   3325046.0     3086089.0        11
# 22   4799284.0     4548382.0        16
# 23   2944813.0     2690667.0        10
# 24   1209357.0     1185845.0         6
# 25   2808605.0     2665579.0        10
# 26    497147.0      456949.0         3
# 27    844227.0      780455.0         5
# 28   1125385.0     1051318.0         6
# 29    744296.0      694316.0         4
# 30   3874046.0     3750211.0        14
# 31    798319.0      704901.0         5
# 32   7721442.0     7375651.0        29
# 33   4741564.0     4551947.0        15
# 34    344360.0      310552.0         3
# 35   5496487.0     5235169.0        18
# 36   1452992.0     1369511.0         7
# 37   2001336.0     1784509.0         7
# 38   6165478.0     5897174.0        20
# 39    464144.0      433068.0         4
# 40   2103027.0     2010762.0         9
# 41    370093.0      345179.0         3
# 42   2508027.0     2393620.0        11
# 43   8969226.0     8562915.0        38
# 44   1131430.0      825907.0         6
# 45    315067.0      273942.0         3
# 46   3984631.0     3750916.0        13
# 47   3317019.0     2964465.0        12
# 48    714423.0      678165.0         5
# 49   2976150.0     2787820.0        10
# 50    255849.0      230392.0         3

# %%
df['Clinton Electors'] = np.round(df['Electors'] * df['Clinton (D).1'] / df['Viable Votes'], 0)

# %%
df['Trump Electors'] = np.round(df['Electors'] * df['Trump (R).1'] / df['Viable Votes'],0)

# %%
df['Repr Electors'] = df['Electors'] - 2.0

# %%
df.head()
# Out:
#   STATE Trump (R) Clinton (D)  Trump (R).1  Clinton (D).1  All Others  \
# 0    AL         9         NaN    1318255.0       729547.0     75570.0
# 1    AK         3         NaN     163387.0       116454.0     38767.0
# 2    AZ        11         NaN    1252401.0      1161167.0    159597.0
# 3    AR         6         NaN     684872.0       380494.0     65310.0
# 4    CA       NaN          55    4483814.0      8753792.0    943998.0
#
#    Total Vote  Viable Votes  Electors  Clinton Electors  Trump Electors  \
# 0   2123372.0     2047802.0         9               3.0             6.0
# 1    318608.0      279841.0         3               1.0             2.0
# 2   2573165.0     2413568.0        11               5.0             6.0
# 3   1130676.0     1065366.0         6               2.0             4.0
# 4  14181604.0    13237606.0        55              36.0            19.0
#
#    Repr Electors
# 0            7.0
# 1            1.0
# 2            9.0
# 3            4.0
# 4           53.0

# %%
df['Clinton Win'] = (df['Clinton (D).1'] > df['Trump (R).1'])
df['Trump Win'] = (df['Trump (R).1'] > df['Clinton (D).1'])

# %%
df['Clinton Electors 2'] = 0.0
df['Trump Electors 2'] = 0.0

# %%
for i in range(len(df['STATE'])):
    df['Clinton Electors 2'][i] = np.round(df['Clinton (D).1'][i] * df['Repr Electors'][i] / df['Viable Votes'][i],0) + (2 if df['Clinton Win'][i] else 0)
    df['Trump Electors 2'][i] = np.round(df['Trump (R).1'][i] * df['Repr Electors'][i] / df['Viable Votes'][i], 0) + (2 if df['Trump Win'][i] else 0)
# Out:
# /Users/erikamundson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/erikamundson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#   STATE Trump (R) Clinton (D)  Trump (R).1  Clinton (D).1  All Others  \
# 0    AL         9         NaN    1318255.0       729547.0     75570.0
# 1    AK         3         NaN     163387.0       116454.0     38767.0
# 2    AZ        11         NaN    1252401.0      1161167.0    159597.0
# 3    AR         6         NaN     684872.0       380494.0     65310.0
# 4    CA       NaN          55    4483814.0      8753792.0    943998.0
#
#    Total Vote  Viable Votes  Electors  Clinton Electors  Trump Electors  \
# 0   2123372.0     2047802.0         9               3.0             6.0
# 1    318608.0      279841.0         3               1.0             2.0
# 2   2573165.0     2413568.0        11               5.0             6.0
# 3   1130676.0     1065366.0         6               2.0             4.0
# 4  14181604.0    13237606.0        55              36.0            19.0
#
#    Repr Electors  Clinton Win  Trump Win  Clinton Electors 2  Trump Electors 2
# 0            7.0        False       True                 2.0               7.0
# 1            1.0        False       True                 0.0               3.0
# 2            9.0        False       True                 4.0               7.0
# 3            4.0        False       True                 1.0               5.0
# 4           53.0         True      False                37.0              18.0

# %%
total_clinton_electors = sum(df['Clinton Electors'])
total_clinton_electors
# Out:
# 270.0

# %%
df['Clinton (D).1'][1] / df['Viable Votes'][1]
# Out:
# 0.4161434528893193

# %%
total_trump_electors = sum(df['Trump Electors'])
total_trump_electors
# Out:
# 268.0

# %%
total_clinton_electors_2 = sum(df['Clinton Electors 2'])
total_clinton_electors_2
# Out:
# 266.0

# %%
total_trump_electors_2 = sum(df['Trump Electors 2'])
total_trump_electors_2
# Out:
# 272.0

# %%
total_clinton_votes = sum(df['Clinton (D).1'])
total_clinton_votes
# Out:
# 65853514.0

# %%
total_trump_votes = sum(df['Trump (R).1'])
total_trump_votes
# Out:
# 62984828.0

# %%
clinton_percent_votes = (total_clinton_votes / (total_clinton_votes + total_trump_votes))
trump_percent_votes = (total_trump_votes / (total_clinton_votes + total_trump_votes))

# %%
np.round(clinton_percent_votes * 538, 0)
# Out:
# 275.0

# %%
np.round(trump_percent_votes * 538, 0)
# Out:
# 263.0

# %%
df['Clinton Actual Electors'] = 0
df['Trump Actual Electors'] = 0
for i in range(len(df['STATE'])):
    df['Clinton Actual Electors'][i] = (df['Electors'][i] if df['Clinton Win'][i] else 0)
    df['Trump Actual Electors'][i] = (df['Electors'][i] if df['Trump Win'][i] else 0)
# Out:
# /Users/erikamundson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/erikamundson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df['Clinton Actual Electors'].sum()
# Out:
# 233

# %%
df['Trump Actual Electors'].sum()
# Out:
# 305

# %%
233+305
# Out:
# 538

# %%
summary = pd.DataFrame(columns = ['Metric', 'Trump', 'Clinton'])

# %%
summary
# Out:
# Empty DataFrame
# Columns: [Metric, Trump, Clinton]
# Index: []

# %%
summary.loc[0] = ['State Popular Vote', 268, 270] 
summary.loc[1] = ['State Popular Vote WTA Senators', 272, 266]
summary.loc[2] = ['Viable Popular Vote * 538', 263, 275]
summary.loc[3] = ['Congressional District', 290, 248]

# %%
summary.loc[4] = ['Actual', 304, 227]
summary.loc[5] = ['Actual w/o Faithless Electors', 305, 233]

# %%
summary = pd.melt(summary, id_vars='Metric', var_name='Candidate', value_name='Electoral Votes')
summary
# Out:
#                              Metric Candidate Electoral Votes
# 0                State Popular Vote     Trump             268
# 1   State Popular Vote WTA Senators     Trump             272
# 2         Viable Popular Vote * 538     Trump             263
# 3            Congressional District     Trump             290
# 4                            Actual     Trump             304
# 5     Actual w/o Faithless Electors     Trump             305
# 6                State Popular Vote   Clinton             270
# 7   State Popular Vote WTA Senators   Clinton             266
# 8         Viable Popular Vote * 538   Clinton             275
# 9            Congressional District   Clinton             248
# 10                           Actual   Clinton             227
# 11    Actual w/o Faithless Electors   Clinton             233

# %%
def show_values_on_bars(axs):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 5
            value = '{}'.format(int(p.get_height()))
            ax.text(_x, _y, value, ha="center", fontweight='bold') 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %%
colors = ["#DE0100", "#0015BC"]
f, ax = plt.subplots(1,1)
sns.set(rc={'figure.figsize':(20,10)})
sns.set_style('whitegrid')
sns.barplot(x='Metric', y='Electoral Votes', data=summary, hue='Candidate', palette = colors, ax=ax)
plt.xlabel('Method', fontsize=12, fontweight='semibold')
plt.ylabel('Electoral Votes', fontsize=12, fontweight='semibold')
plt.title('2016 Electoral Votes by Method', fontsize=12, fontweight='bold')
plt.ylim(0, 350)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
show_values_on_bars(ax)
plt.savefig('electors.png', bbox_inches='tight')
plt.show()
